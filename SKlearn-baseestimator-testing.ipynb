# %% [markdown]
# # sci-kit learns tests
#
# I want to use the sk-learn API to use gridsearch for selecting the best inclusion threshold. Therefore, I need to check if my model is a BaseEstimator.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
from quickrules.data_handling import get_dataset
from pathlib import Path
from fuzzyroughrules.rule_induction_base import RuleGenerator
from fuzzyroughrules.approximations import LowerApproximation
from sklearn.metrics import balanced_accuracy_score
from sklearn.utils.estimator_checks import check_estimator

# %%
rg = RuleGenerator()

# %%
check_estimator(rg)
# Out:
# Restricted license - for non-production use only - expires 2024-10-28

# %% [markdown]
# I get a list index out of range error on list credibility

# %%
name = 'ecoli'  # 'bupa
nr = 7

# %%
x_train, y_train, t_train = get_dataset(
    Path.cwd() / 'keel-data' / f'{name}-10-fold',
    f"{nr}tra",
    get_datatypes=True
)
x_test, y_test = get_dataset(
    Path.cwd() / 'keel-data' / f'{name}-10-fold',
    f"{nr}tst"
)

# %%
classes = list(np.unique(np.append(y_train, y_test)))
y_train = np.array([classes.index(label) for label in y_train])
y_test = np.array([classes.index(label) for label in y_test])

# %%
model = RuleGenerator()
model.fit(x_train, y_train, _)
# Out:
# RuleGenerator(approximation_type=<class 'fuzzyroughrules.approximations.LowerApproximation'>, approximation_kwargs={}, inclusion_measure_type=<class 'fuzzyroughrules.operators.ImplicatorInclusion'>, inclusion_measure_kwargs={}, with_reducts=True, optimise_attribute_order=False, attribute_ordering_type=<class 'fuzzyroughrules.feature_preprocessors.QuickReduct'>, attribute_ordering_kwargs={}, optimise_slopes=False, slope_options=[0.001, 0.01, 0.1, 0.5, 1], covering_threshold=1e-06, inclusion_threshold=0.9999)

# %%
balanced_accuracy_score(y_test, model.predict(x_test))
# Out:
# /Users/henri/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2184: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 0.7707142857142857

# %%
from sklearn.preprocessing import LabelEncoder

y_train = ['a', 'b', 'c']
y_test = ['b', 'c', 'd']

# %%
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train)

# %%
y_train
# Out:
# array([0, 1, 2])

# %%
y_test = encoder.transform(y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/utils/_encode.py:224, in _encode(values, uniques, check_unknown)
#     223 try:
# --> 224     return _map_to_integer(values, uniques)
#     225 except KeyError as e:
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/utils/_encode.py:164, in _map_to_integer(values, uniques)
#     163 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 164 return np.array([table[v] for v in values])
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/utils/_encode.py:164, in <listcomp>(.0)
#     163 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 164 return np.array([table[v] for v in values])
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/utils/_encode.py:158, in _nandict.__missing__(self, key)
#     157     return self.nan_value
# --> 158 raise KeyError(key)
#
# KeyError: 'd'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 y_test = encoder.transform(y_test)
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:139, in LabelEncoder.transform(self, y)
#     136 if _num_samples(y) == 0:
#     137     return np.array([])
# --> 139 return _encode(y, uniques=self.classes_)
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/utils/_encode.py:226, in _encode(values, uniques, check_unknown)
#     224         return _map_to_integer(values, uniques)
#     225     except KeyError as e:
# --> 226         raise ValueError(f"y contains previously unseen labels: {str(e)}")
#     227 else:
#     228     if check_unknown:
#
# ValueError: y contains previously unseen labels: 'd'
