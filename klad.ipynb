# %% [markdown]
# # Testing if QuickRules works correctly

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from quickrules.data_handling import get_dataset
from pathlib import Path

x_train, y_train = get_dataset(Path.cwd() / 'keel-data' / 'australian-10-fold', '1tra')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from quickrules.data_handling import get_dataset
#       2 from pathlib import Path
#       4 x_train, y_train = get_dataset(Path.cwd() / 'keel-data' / 'australian-10-fold', '1tra')
#
# ModuleNotFoundError: No module named 'quickrules'
