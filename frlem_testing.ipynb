# %% [markdown]
# # Testing LEM variants

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
from fuzzy.lem_models import FRLEMModel
from quickrules.data_handling import test_save

# %%
data_sets = [
    'australian',
    'cleveland',
    'glass',
    'heart',
    'ionosphere',
    'pima',
    'wine',
    'bupa',
    'saheart',
    'wisconsin',
    'crx',
    'ecoli',
    'haberman',
    'mammographic'
             ]

# %%
model = FRLEMModel()

# %%
data_path = Path.cwd() / 'keel-data'
results_path = Path.cwd() / 'frlem-results'

# %%
test_save(model=model,
          datasets_folder=data_path,
          results_folder=results_path,
          get_rules=False,
          print_info=False,
          exclude=None,
          include=data_sets,
          verbose=True
          )
# Out:
# ecoli
# wisconsin
# saheart
# haberman
# cleveland
# crx
# bupa
# heart
# australian
# mammographic
# glass
# pima
# wine
# ionosphere
