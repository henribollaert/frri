# %%
# %load_ext autoreload
# %autoreload 2

# %%
# from fuzzyroughrules.rule_induction_base import RuleGenerator
# from fuzzyroughrules.approximations import MulticlassMSECVXApproximation
# from fuzzyroughrules.frfs_frri import FRFSRuleGenerator, OFRFS
from fuzzyroughrules.filter_frri import Filter, FilterRuleGenerator, mutual_info_classif, r_regression
from hhelper.tester import test_save
from pathlib import Path

# %%
def_sets = [
    'australian',
    'bupa',
    'cleveland',
    'crx',
    'ecoli',
    'glass',
    'haberman',
    'heart',
    'ionosphere',
    'pima',
    # 'saheart',
    'spectfheart',
    'winequality-red',
    'wine',
    'wisconsin',
    'yeast'
    # 'automobile'
    # 'bands'
    # 'contraceptive',
    # 'dermatology', run base again
    # 'german',
    # 'movement',
    # 'sonar',
    # 'vehicle',
    # 'vowel',
]

data_sets = [  # actual set for QR
    'australian',
     'bands',
     'bupa',
     'cleveland',
     'dermatology',
     'ecoli',
     'glass',  
     'heart',
     'ionosphere',
     'pima',
     'sonar',  # 70 features!
     'spectfheart',
     'vehicle',
     'vowel',
     'wine',
     'winequality-red',  # temp uit voor inclusion tests
     'wisconsin',
     'yeast'
]

extra_data_sets = [  # commented out any above 2000 samples
    'banana',
    'bands',
    # 'contraceptive', ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1325, 1325) + inhomogeneous part.
    'dermatology',
    # 'marketing', Value error as well
    'movement',
    # 'page-blocks',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4924, 4924) + inhomogeneous part
    'phoneme',
    'ring',
    'satimage',
    'segment',
    'sonar',
    # 'spambase', #  setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4137, 4137) + inhomogeneous part.
    'spectfheart',
    # 'texture',  # GurobiError: Model too large for size-limited license; visit https://www.gurobi.com/free-trial for a full license
    # 'titanic',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1980, 1980) + inhomogeneous part.
    # 'thyroid',
    'twonorm',
    'vehicle',
    'vowel',
    'wdbc',
    'winequality-red',
    'winequality-white',
    'yeast'
]

cat_datasets = [
    'automobile',
    'crx',
    'german',
    'saheart'
]


main_sets = [  # actual set for QR
    'australian',
     # 'automobile', # cat feats
     'bands',
     'bupa',
     'cleveland',
     # 'contraceptive', # cannot retrieve attribute x, has always been on this dataset
     # 'crx', # cat feats
     'dermatology',
     'ecoli',
     # 'german', # cat feats
     'glass',  # error on 1 fold
     # 'haberman', # cannot retrieve attribute x, has always been on this dataset
     'heart',
     'ionosphere',
     # 'mammographic',  # cannot retrieve attribute x, has always been on this dataset
     'pima',
     # 'saheart', # cat feats
     'sonar',  # 70 features!
     'spectfheart',
     'vehicle',
     'vowel',
     'wine',
     # 'winequality-red',  # too slow for now (13/09) #todo
     'wisconsin',
     'yeast'  # errors on some folds
]

extra_sets = [
    'newthyroid',
    'appendicitis',
    'iris',
    'tae',
    'hepatitis',
]

# %%
model = FilterRuleGenerator(
    attribute_ratio=0.8,
    filter_type=Filter,
    metric=r_regression,
    # approximation=MulticlassMSECVXApproximation(),
    # apply_relabelling=True,
    # relabelling_threshold=.05,
    # covering_threshold=.50 - 1e-6,
    # inclusion_threshold=0.5,
    # use_gran_approx=True,
    # discard_uncertain_objects=True,
    # certainty_threshold=.70,
    # add_uncovered_objects=False,
    # print_nr_of_rule_candidates=True,
    # print_changes=True
)
test_save(
    model=model,
    datasets_folder=Path.cwd() / 'keel-data',
    results_folder=Path.cwd() / 'results' / 'ijcrs-retest' / 'pcc-0.8',
    get_rules=True,
    print_info=True,
    include=data_sets,
    verbose=True,
    encode_labels=True,
)
# Out:
# ecoli
# wisconsin
# sonar
# dermatology
# cleveland
# winequality-red
# spectfheart
# bupa
# yeast
# heart
# australian
# glass
# pima
# vowel
# vehicle
# wine
# ionosphere
# bands

# %%
# i seem to get more problems now
# try again on ecoli
# then try with .99 as the threshold
# we really need to figure out how to solve this optimisation problem netter
# hoe zou het komen dat we hier nu voorspellingsproblemen krijgen ook?
# bovenstaande errors staan een foldnr te laag, gefixed 13/09/23@17:58

# %%
0

# %%
for i in range(10):
    print(0.99 + i/1000)
# Out:
# 0.99
# 0.991
# 0.992
# 0.993
# 0.994
# 0.995
# 0.996
# 0.997
# 0.998
# 0.999
