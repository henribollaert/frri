# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fuzzyroughrules.rule_induction_base import RuleGenerator
from fuzzyroughrules.approximations import OWALowerApproximation, MulticlassMSECVXApproximation, MulticlassMAECVXApproximation
from quickrules.data_handling import test_save
from pathlib import Path

# %%
def_sets = [
    'australian',
    'bupa',
    'cleveland',
    'crx',
    'ecoli',
    'glass',
    'haberman',
    'heart',
    'ionosphere',
    'pima',
    # 'saheart',
    'spectfheart',
    'winequality-red',
    'wine',
    'wisconsin',
    'yeast'
    # 'automobile'
    # 'bands'
    # 'contraceptive',
    # 'dermatology', run base again
    # 'german',
    # 'movement',
    # 'sonar',
    # 'vehicle',
    # 'vowel',
]

data_sets = [  # actual set for QR
    'australian',
     'bands',
     'bupa',
     'cleveland',
     'dermatology',
     'ecoli',
     'glass',  
    # 'haberman',
     'heart',
     'ionosphere',
     'pima',
     'sonar',  # 70 features!
     'spectfheart',
     'vehicle',
     # 'vowel',
     'wine',
     # 'winequality-red',  # temp uit voor inclusion tests
     'wisconsin',
     'yeast'
]

# data_sets = [
#     'australian',
#     'cleveland',
#     'glass',
#     'heart',
#     'ionosphere',
#     'pima',
#     'wine',
#     'bupa',
#     'wisconsin',
#     # 'balance',  # same as monk
#     'ecoli',
#     # 'haberman',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (275, 275) + inhomogeneous part.
#     # 'monk',  # problems with list indices again
#     # 'mammographic',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (747, 747) + inhomogeneous part.
# ]

extra_data_sets = [  # commented out any above 2000 samples
    'banana',
    'bands',
    # 'contraceptive', ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1325, 1325) + inhomogeneous part.
    'dermatology',
    # 'marketing', Value error as well
    'movement',
    # 'page-blocks',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4924, 4924) + inhomogeneous part
    'phoneme',
    'ring',
    'satimage',
    'segment',
    'sonar',
    # 'spambase', #  setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4137, 4137) + inhomogeneous part.
    'spectfheart',
    # 'texture',  # GurobiError: Model too large for size-limited license; visit https://www.gurobi.com/free-trial for a full license
    # 'titanic',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1980, 1980) + inhomogeneous part.
    # 'thyroid',
    'twonorm',
    'vehicle',
    'vowel',
    'wdbc',
    'winequality-red',
    'winequality-white',
    'yeast'
]

cat_datasets = [
    'automobile',
    'crx',
    'german',
    'saheart'
]


main_sets = [  # actual set for QR
    'australian',
     # 'automobile', # cat feats
     'bands',
     'bupa',
     'cleveland',
     # 'contraceptive', # cannot retrieve attribute x, has always been on this dataset
     # 'crx', # cat feats
     'dermatology',
     'ecoli',
     # 'german', # cat feats
     'glass',  # error on 1 fold
     # 'haberman', # cannot retrieve attribute x, has always been on this dataset
     'heart',
     'ionosphere',
     # 'mammographic',  # cannot retrieve attribute x, has always been on this dataset
     'pima',
     # 'saheart', # cat feats
     'sonar',  # 70 features!
     'spectfheart',
     'vehicle',
     'vowel',
     'wine',
     # 'winequality-red',  # too slow for now (13/09) #todo
     'wisconsin',
     'yeast'  # errors on some folds
]

# %%
model = RuleGenerator(
    approximation=MulticlassMAECVXApproximation(),
    apply_relabelling=True,
    print_changes=True,
    covering_threshold=.5 - 1e-6,
    inclusion_threshold=.95
)
test_save(
    model=model,
    datasets_folder=Path.cwd() / 'keel-data',
    results_folder=Path.cwd() / 'results' / 'multiclassMAECVX' / 'relabelling-reducts-cov50-inc95',
    get_rules=True,
    print_info=True,
    include=data_sets,
    verbose=True,
    encode_labels=True,
)
# Out:
# ecoli
# 63 labels out of 302 were changed.
# 70 labels out of 302 were changed.
# 60 labels out of 302 were changed.
# 63 labels out of 302 were changed.
# 67 labels out of 302 were changed.
# 59 labels out of 302 were changed.
# 66 labels out of 303 were changed.
# 65 labels out of 303 were changed.
# 62 labels out of 303 were changed.
# 66 labels out of 303 were changed.
# wisconsin
# 18 labels out of 614 were changed.
# 21 labels out of 614 were changed.
# 21 labels out of 616 were changed.
# 24 labels out of 617 were changed.
# 20 labels out of 615 were changed.
# 21 labels out of 613 were changed.
# 24 labels out of 615 were changed.
# 22 labels out of 614 were changed.
# 18 labels out of 613 were changed.
# 23 labels out of 616 were changed.
# sonar
# 9 labels out of 187 were changed.
# 16 labels out of 187 were changed.
# 14 labels out of 187 were changed.
# 8 labels out of 187 were changed.
# 11 labels out of 187 were changed.
# 13 labels out of 187 were changed.
# 16 labels out of 187 were changed.
# 7 labels out of 187 were changed.
# 15 labels out of 188 were changed.
# 6 labels out of 188 were changed.
# dermatology
# 2 labels out of 323 were changed.
# 5 labels out of 322 were changed.
# 7 labels out of 321 were changed.
# 1 labels out of 322 were changed.
# 2 labels out of 321 were changed.
# 3 labels out of 322 were changed.
# 2 labels out of 323 were changed.
# 0 labels out of 323 were changed.
# 3 labels out of 322 were changed.
# 3 labels out of 323 were changed.
# cleveland
# 23 labels out of 267 were changed.
# 24 labels out of 268 were changed.
# 26 labels out of 267 were changed.
# 21 labels out of 268 were changed.
# 20 labels out of 267 were changed.
# 20 labels out of 267 were changed.
# 25 labels out of 267 were changed.
# 24 labels out of 269 were changed.
# 25 labels out of 266 were changed.
# 23 labels out of 267 were changed.
# spectfheart
# 49 labels out of 240 were changed.
# 49 labels out of 240 were changed.
# 49 labels out of 240 were changed.
# 49 labels out of 240 were changed.
# 49 labels out of 240 were changed.
# 50 labels out of 240 were changed.
# 50 labels out of 240 were changed.
# 50 labels out of 241 were changed.
# 50 labels out of 241 were changed.
# 50 labels out of 241 were changed.
# bupa
# 129 labels out of 310 were changed.
# 130 labels out of 310 were changed.
# 130 labels out of 314 were changed.
# 130 labels out of 311 were changed.
# 130 labels out of 310 were changed.
# 132 labels out of 310 were changed.
# 131 labels out of 310 were changed.
# 130 labels out of 310 were changed.
# 128 labels out of 310 were changed.
# 130 labels out of 310 were changed.
# yeast
# 122 labels out of 1335 were changed.
# 150 labels out of 1335 were changed.
# 150 labels out of 1335 were changed.
# 135 labels out of 1335 were changed.
# 134 labels out of 1336 were changed.
# 142 labels out of 1336 were changed.
# 130 labels out of 1336 were changed.
# 132 labels out of 1336 were changed.
# 136 labels out of 1336 were changed.
# 128 labels out of 1336 were changed.
# heart
# 27 labels out of 243 were changed.
# 33 labels out of 243 were changed.
# 30 labels out of 243 were changed.
# 29 labels out of 243 were changed.
# 28 labels out of 243 were changed.
# 26 labels out of 243 were changed.
# 33 labels out of 243 were changed.
# 30 labels out of 243 were changed.
# 25 labels out of 243 were changed.
# 29 labels out of 243 were changed.
# australian
# 76 labels out of 621 were changed.
# 79 labels out of 621 were changed.
# 84 labels out of 621 were changed.
# 80 labels out of 621 were changed.
# 76 labels out of 621 were changed.
# 77 labels out of 621 were changed.
# 71 labels out of 621 were changed.
# 84 labels out of 621 were changed.
# 70 labels out of 621 were changed.
# 79 labels out of 621 were changed.
# glass
# 15 labels out of 191 were changed.
# 15 labels out of 191 were changed.
# 10 labels out of 191 were changed.
# 11 labels out of 192 were changed.
# 20 labels out of 192 were changed.
# 13 labels out of 192 were changed.
# 17 labels out of 193 were changed.
# 15 labels out of 194 were changed.
# 14 labels out of 194 were changed.
# 20 labels out of 196 were changed.
# pima
# 238 labels out of 691 were changed.
# 237 labels out of 690 were changed.
# 239 labels out of 692 were changed.
# 238 labels out of 691 were changed.
# 239 labels out of 691 were changed.
# 241 labels out of 692 were changed.
# 239 labels out of 691 were changed.
# 239 labels out of 692 were changed.
# 238 labels out of 691 were changed.
# 238 labels out of 691 were changed.
# vehicle
# 28 labels out of 761 were changed.
# 30 labels out of 761 were changed.
# 20 labels out of 761 were changed.
# 24 labels out of 761 were changed.
# 24 labels out of 761 were changed.
# 28 labels out of 761 were changed.
# 24 labels out of 762 were changed.
# 26 labels out of 762 were changed.
# 27 labels out of 762 were changed.
# 26 labels out of 762 were changed.
# wine
# 0 labels out of 160 were changed.
# 1 labels out of 160 were changed.
# 0 labels out of 160 were changed.
# 1 labels out of 160 were changed.
# 1 labels out of 161 were changed.
# 1 labels out of 161 were changed.
# 1 labels out of 160 were changed.
# 2 labels out of 160 were changed.
# 1 labels out of 160 were changed.
# 2 labels out of 160 were changed.
# ionosphere
# 32 labels out of 315 were changed.
# 38 labels out of 316 were changed.
# 37 labels out of 316 were changed.
# 35 labels out of 316 were changed.
# 34 labels out of 316 were changed.
# 35 labels out of 316 were changed.
# 33 labels out of 316 were changed.
# 36 labels out of 316 were changed.
# 34 labels out of 316 were changed.
# 36 labels out of 316 were changed.
# bands
# 115 labels out of 327 were changed.
# 113 labels out of 327 were changed.
# 113 labels out of 327 were changed.
# 118 labels out of 331 were changed.
# 110 labels out of 323 were changed.
# 118 labels out of 332 were changed.
# 116 labels out of 328 were changed.
# 113 labels out of 325 were changed.
# 117 labels out of 331 were changed.
# 118 labels out of 334 were changed.

# %%
# i seem to get more problems now
# try again on ecoli
# then try with .99 as the threshold
# we really need to figure out how to solve this optimisation problem netter
# hoe zou het komen dat we hier nu voorspellingsproblemen krijgen ook?
# bovenstaande errors staan een foldnr te laag, gefixed 13/09/23@17:58

# %%
0

# %%
for i in range(10):
    print(0.99 + i/1000)
# Out:
# 0.99
# 0.991
# 0.992
# 0.993
# 0.994
# 0.995
# 0.996
# 0.997
# 0.998
# 0.999
