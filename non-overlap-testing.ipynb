# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fuzzyroughrules.non_overlap_rules import RuleGenerator
from quickrules.data_handling import test_save
from pathlib import Path

# %%
def_sets = [
    'australian',
    'bupa',
    'cleveland',
    'crx',
    'ecoli',
    # 'haberman',
    'heart',
    'ionosphere',
    'pima',
    # 'saheart',
    'wine',
    'wisconsin',
    'automobile'
    'bands'
    'contraceptive',
    # 'dermatology', run base again
    'german',
    'movement',
    'sonar',
    'spectfheart',
    'vehicle',
    'vowel',
]


data_sets = [
    'australian',
    'cleveland',
    'glass',
    'heart',
    'ionosphere',
    'pima',
    'wine',
    'bupa',
    'wisconsin',
    # 'balance',  # same as monk
    'ecoli',
    # 'haberman',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (275, 275) + inhomogeneous part.
    # 'monk',  # problems with list indices again
    # 'mammographic',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (747, 747) + inhomogeneous part.
]

extra_data_sets = [  # commented out any above 2000 samples
    'banana',
    'bands',
    # 'contraceptive', ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1325, 1325) + inhomogeneous part.
    'dermatology',
    # 'marketing', Value error as well
    'movement',
    # 'page-blocks',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4924, 4924) + inhomogeneous part
    'phoneme',
    'ring',
    'satimage',
    'segment',
    'sonar',
    # 'spambase', #  setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4137, 4137) + inhomogeneous part.
    'spectfheart',
    # 'texture',  # GurobiError: Model too large for size-limited license; visit https://www.gurobi.com/free-trial for a full license
    # 'titanic',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1980, 1980) + inhomogeneous part.
    # 'thyroid',
    'twonorm',
    'vehicle',
    'vowel',
    'wdbc',
    'winequality-red',
    'winequality-white',
    'yeast'
]

cat_datasets = [
    'automobile',
    'crx',
    'german',
    'saheart'
]

# %%
test_save(
    model=RuleGenerator(with_reducts=True),
    datasets_folder=Path.cwd() / 'keel-data',
    results_folder=Path.cwd() / 'non-overlap-rules',
    get_rules=True,
    print_info=True,
    include=def_sets,
    verbose=True,
    encode_labels=True
)
# Out:
# ecoli
# wisconsin
# sonar
# cleveland
# crx
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 test_save(
#       2     model=RuleGenerator(with_reducts=True),
#       3     datasets_folder=Path.cwd() / 'keel-data',
#       4     results_folder=Path.cwd() / 'non-overlap-rules',
#       5     get_rules=True,
#       6     print_info=True,
#       7     include=def_sets,
#       8     verbose=True,
#       9     encode_labels=True
#      10 )
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/quickrules/data_handling.py:142, in test_save(model, datasets_folder, results_folder, get_rules, print_info, exclude, include, verbose, nr_of_folds, encode_labels)
#     139         np.save(f, np.array([1, 3]))
#     141 # create the rules
# --> 142 model.fit(x_train, y_train, t_train)
#     144 # query on the test set
#     145 predictions = model.predict(x_test)
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/fuzzyroughrules/non_overlap_rules.py:112, in RuleGenerator.fit(self, data, labels, types)
#     110 self.n_classes = len(np.unique(labels))
#     111 self.scaler = self.scaler_type()
# --> 112 self.scaler.fit(self.X)
#     113 self.X_scaled = self.scaler.transform(self.X)
#     114 self.rel_matrix_x = fo.triangular_similarity(self.X_scaled, self.X_scaled)
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:427, in MinMaxScaler.fit(self, X, y)
#     425 # Reset internal state before fitting
#     426 self._reset()
# --> 427 return self.partial_fit(X, y)
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:466, in MinMaxScaler.partial_fit(self, X, y)
#     460     raise TypeError(
#     461         "MinMaxScaler does not support sparse input. "
#     462         "Consider using MaxAbsScaler instead."
#     463     )
#     465 first_pass = not hasattr(self, "n_samples_seen_")
# --> 466 X = self._validate_data(
#     467     X,
#     468     reset=first_pass,
#     469     dtype=FLOAT_DTYPES,
#     470     force_all_finite="allow-nan",
#     471 )
#     473 data_min = np.nanmin(X, axis=0)
#     474 data_max = np.nanmax(X, axis=0)
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/base.py:535, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     533     raise ValueError("Validation should be done on X, y or both.")
#     534 elif not no_val_X and no_val_y:
# --> 535     X = check_array(X, input_name="X", **check_params)
#     536     out = X
#     537 elif no_val_X and not no_val_y:
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:877, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     875         array = xp.astype(array, dtype, copy=False)
#     876     else:
# --> 877         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     878 except ComplexWarning as complex_warning:
#     879     raise ValueError(
#     880         "Complex data not supported\n{}\n".format(array)
#     881     ) from complex_warning
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/venv/lib/python3.10/site-packages/sklearn/utils/_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# ValueError: could not convert string to float: 'a'

# %%
import numpy as np

with open(Path.cwd() / 'test.npy', 'wb') as f:
    np.save(f, np.array([1,2]))

# %%
from quickrules.data_handling import get_dataset
# Out:
# array([1, 2])

# %%
classes = np.load(str(Path.cwd() / 'non-overlap-rules' / 'bands' / 'fold1'/"label_encoding_fold1.npy"))

# %%
classes
# Out:
# array(['band', 'noband'], dtype='<U6')
