# %%
# %load_ext autoreload
# %autoreload 2

# %%
# from fuzzyroughrules.non_overlap_rules import RuleGenerator
# from fuzzyroughrules.lower_approx_rules import RuleGenerator
from fuzzyroughrules.rule_induction_base import RuleGenerator
from fuzzyroughrules.approximations import LowerApproximation, MulticlassMSECVXApproximation
from fuzzyroughrules.operators import ImplicatorInclusion
from quickrules.data_handling import test_save
from pathlib import Path

# %%
def_sets = [
    'australian',
    'bupa',
    'cleveland',
    'crx',
    'ecoli',
    'glass',
    'haberman',
    'heart',
    'ionosphere',
    'pima',
    # 'saheart',
    'spectfheart',
    'winequality-red',
    'wine',
    'wisconsin',
    'yeast'
    # 'automobile'
    # 'bands'
    # 'contraceptive',
    # 'dermatology', run base again
    # 'german',
    # 'movement',
    # 'sonar',
    # 'vehicle',
    # 'vowel',
]


data_sets = [
    'australian',
    'cleveland',
    'glass',
    'heart',
    'ionosphere',
    'pima',
    'wine',
    'bupa',
    'wisconsin',
    # 'balance',  # same as monk
    'ecoli',
    # 'haberman',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (275, 275) + inhomogeneous part.
    # 'monk',  # problems with list indices again
    # 'mammographic',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (747, 747) + inhomogeneous part.
]

extra_data_sets = [  # commented out any above 2000 samples
    'banana',
    'bands',
    # 'contraceptive', ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1325, 1325) + inhomogeneous part.
    'dermatology',
    # 'marketing', Value error as well
    'movement',
    # 'page-blocks',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4924, 4924) + inhomogeneous part
    'phoneme',
    'ring',
    'satimage',
    'segment',
    'sonar',
    # 'spambase', #  setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4137, 4137) + inhomogeneous part.
    'spectfheart',
    # 'texture',  # GurobiError: Model too large for size-limited license; visit https://www.gurobi.com/free-trial for a full license
    # 'titanic',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1980, 1980) + inhomogeneous part.
    # 'thyroid',
    'twonorm',
    'vehicle',
    'vowel',
    'wdbc',
    'winequality-red',
    'winequality-white',
    'yeast'
]

cat_datasets = [
    'automobile',
    'crx',
    'german',
    'saheart'
]


main_sets = [  # actual set for QR
    'australian',
     # 'automobile', # cat feats
     'bands',
     'bupa',
     'cleveland',
     # 'contraceptive', # cannot retrieve attribute x, has always been on this dataset
     # 'crx', # cat feats
     'dermatology',
     'ecoli',
     # 'german', # cat feats
     'glass',  # error on 1 fold
     # 'haberman', # cannot retrieve attribute x, has always been on this dataset
     'heart',
     'ionosphere',
     # 'mammographic',  # cannot retrieve attribute x, has always been on this dataset
     'pima',
     # 'saheart', # cat feats
     'sonar',  # 70 features!
     'spectfheart',
     'vehicle',
     'vowel',
     'wine',
     # 'winequality-red',  # too slow for now (13/09)
     'wisconsin',
     'yeast'  # errors on some folds
]

# %%
model = RuleGenerator(
    LowerApproximation(),
    inclusion_measure=ImplicatorInclusion(),
    inclusion_threshold=0.99,
    with_reducts=True
)

# %%
test_save(
    model=model,
    datasets_folder=Path.cwd() / 'keel-data',
    results_folder=Path.cwd() / 'lower-approx-luka-impl-incl.99', #  'non-overlap-rules-def_sets',
    get_rules=True,
    print_info=True,
    include=main_sets,
    verbose=True,
    encode_labels=True,
    # save_probas=True
)
# Out:
# ecoli
# wisconsin
# sonar
# dermatology
# haberman
# cleveland
# contraceptive
# Restricted license - for non-production use only - expires 2024-10-28
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 0.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 1.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 2.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 3.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 4.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 5.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 6.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 7.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 8.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 9.', "Unable to retrieve attribute 'x'"]
# spectfheart
# bupa
# yeast
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while predicting on fold 3.', 'zero-size array to reduction operation maximum which has no identity']
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while predicting on fold 5.', 'zero-size array to reduction operation maximum which has no identity']
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while predicting on fold 9.', 'zero-size array to reduction operation maximum which has no identity']
# heart
# australian
# mammographic
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 0.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 1.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 2.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 3.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 4.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 5.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 6.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 7.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 8.', "Unable to retrieve attribute 'x'"]
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while training on fold 9.', "Unable to retrieve attribute 'x'"]
# glass
# ['@non-overlap-rules-base\n@approximation: LowerApproximation()\n@scaler: MinMaxScaler()', 'Error while predicting on fold 1.', 'zero-size array to reduction operation maximum which has no identity']
# pima
# vowel
# vehicle
# wine
# ionosphere
# bands

# %%
# i seem to get more problems now
# try again on ecoli
# then try with .99 as the threshold
# we really need to figure out how to solve this optimisation problem netter
# hoe zou het komen dat we hier nu voorspellingsproblemen krijgen ook?
# bovenstaande errors staan een foldnr te laag, gefixed 13/09/23@17:58

# %%
0
# Out:
# 0
