# %%
# %load_ext autoreload
# %autoreload 2

# %%
# from fuzzyroughrules.non_overlap_rules import RuleGenerator
# from fuzzyroughrules.lower_approx_rules import RuleGenerator
from fuzzyroughrules.rule_induction_base import RuleGenerator
from fuzzyroughrules.approximations import LowerApproximation
from quickrules.data_handling import test_save
from pathlib import Path

# %%
glass_sets = [
    'glass',
    'heart'
]

def_sets = [
    'australian',
    'bupa',
    'cleveland',
    # 'crx',
    'ecoli',
    'glass',
    # 'haberman',
    'heart',
    'ionosphere',
    'pima',
    # 'saheart',
    'spectfheart',
    'winequality-red',
    'wine',
    'wisconsin',
    'yeast'
    # 'automobile'
    # 'bands'
    # 'contraceptive',
    # 'dermatology', run base again
    # 'german',
    # 'movement',
    # 'sonar',
    # 'vehicle',
    # 'vowel',
]


data_sets = [
    'australian',
    'cleveland',
    'glass',
    'heart',
    'ionosphere',
    'pima',
    'wine',
    'bupa',
    'wisconsin',
    # 'balance',  # same as monk
    'ecoli',
    # 'haberman',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (275, 275) + inhomogeneous part.
    # 'monk',  # problems with list indices again
    # 'mammographic',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (747, 747) + inhomogeneous part.
]

extra_data_sets = [  # commented out any above 2000 samples
    'banana',
    'bands',
    # 'contraceptive', ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1325, 1325) + inhomogeneous part.
    'dermatology',
    # 'marketing', Value error as well
    'movement',
    # 'page-blocks',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4924, 4924) + inhomogeneous part
    'phoneme',
    'ring',
    'satimage',
    'segment',
    'sonar',
    # 'spambase', #  setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4137, 4137) + inhomogeneous part.
    'spectfheart',
    # 'texture',  # GurobiError: Model too large for size-limited license; visit https://www.gurobi.com/free-trial for a full license
    # 'titanic',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1980, 1980) + inhomogeneous part.
    # 'thyroid',
    'twonorm',
    'vehicle',
    'vowel',
    'wdbc',
    'winequality-red',
    'winequality-white',
    'yeast'
]

cat_datasets = [
    'automobile',
    'crx',
    'german',
    'saheart'
]


main_sets = [  # i have quickrules results for all these sets
    'australian',
    'automobile',
    'bands',
    'bupa',
    'cleveland',
    'contraceptive',
    'crx',
    'dermatology',
    'ecoli',
    'german',
    'glass',
    'haberman',
    'heart',
    'ionosphere',
    'mammographic',
    'pima',
    # 'saheart',  # categorical
    # 'sonar',  # 70 features!
    'spectfheart',
    'vehicle',
    'vowel',
    'wine',
    'winequality-red',
    'wisconsin',
    'yeast'
]

# %%
model = RuleGenerator(LowerApproximation(), with_reducts=True)

# %%
test_save(
    model=model,
    datasets_folder=Path.cwd() / 'keel-data',
    results_folder=Path.cwd() / 'lower-approx-new-impl-test', #  'non-overlap-rules-def_sets',
    get_rules=True,
    print_info=True,
    include=def_sets,
    verbose=True,
    encode_labels=True
)
# Out:
# ecoli
# Restricted license - for non-production use only - expires 2024-10-28
# wisconsin
# cleveland
# winequality-red
# spectfheart
# bupa
# yeast
# heart
# australian
# glass
# pima
# wine
# ionosphere

# %%
import numpy as np

with open(Path.cwd() / 'test.npy', 'wb') as f:
    np.save(f, np.array([1,2]))
# Out:
# ['australian', 'bupa', 'cleveland', 'ecoli', 'glass', 'haberman', 'heart', 'ionosphere', 'pima', 'spectfheart', 'winequality-red', 'wine', 'wisconsin', 'yeast', 'bands', 'contraceptive', 'dermatology', 'movement', 'sonar', 'vehicle', 'vowel']

# %%
from quickrules.data_handling import get_dataset
# Out:
# array([1, 2])

# %%
classes = np.load(str(Path.cwd() / 'non-overlap-rules' / 'bands' / 'fold1'/"label_encoding_fold1.npy"))

# %%
classes
# Out:
# array(['band', 'noband'], dtype='<U6')

# %%
import numpy as np

a = np.zeros((10, 10))
a
# Out:
# array([[0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000]])

# %%
a[0,:] = np.ones(10)

# %%
a
# Out:
# array([[1.00000, 1.00000, 1.00000, 1.00000, 1.00000, 1.00000, 1.00000,
#         1.00000, 1.00000, 1.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000],
#        [0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000, 0.00000,
#         0.00000, 0.00000, 0.00000]])
