# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fuzzyroughrules.non_overlap_rules import RuleGenerator
from quickrules.data_handling import test_save
from pathlib import Path

# %%
data_sets = [
    'australian',
    'cleveland',
    'glass',
    'heart',
    'ionosphere',
    'pima',
    'wine',
    'bupa',
    'wisconsin',
    # 'balance',  # same as monk
    'ecoli',
    # 'haberman',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (275, 275) + inhomogeneous part.
    # 'monk',  # problems with list indices again
    # 'mammographic',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (747, 747) + inhomogeneous part.
]

extra_data_sets = [  # commented out any above 2000 samples
    'banana',
    'bands',
    # 'contraceptive', ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1325, 1325) + inhomogeneous part.
    'dermatology',
    'marketing',
    'movement',
    # 'page-blocks',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4924, 4924) + inhomogeneous part
    'phoneme',
    'ring',
    'satimage',
    'segment',
    'sonar',
    # 'spambase', #  setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4137, 4137) + inhomogeneous part.
    'spectfheart',
    # 'texture',  # GurobiError: Model too large for size-limited license; visit https://www.gurobi.com/free-trial for a full license
    # 'titanic',  # ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1980, 1980) + inhomogeneous part.
    # 'thyroid',
    'twonorm',
    'vehicle',
    'vowel',
    'wdbc',
    'winequality-red',
    'winequality-white',
    'yeast'
]

cat_datasets = [
    'automobile',
    'crx',
    'german',
    'saheart'
]

# %%
test_save(
    model=RuleGenerator(with_reducts=True),
    datasets_folder=Path.cwd() / 'keel-data',
    results_folder=Path.cwd() / 'non-overlap-rules',
    get_rules=True,
    print_info=True,
    include=extra_data_sets,
    verbose=True,
    encode_labels=True
)
# Out:
# wdbc
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# sonar
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 33
# 32
# dermatology
# 34
# 34
# 34
# 34
# 34
# 34
# 34
# 34
# 34
# 34
# winequality-red
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# spectfheart
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# yeast
# 31
# 31
# 32
# 32
# 32
# 32
# 32
# 31
# 32
# 31
# marketing
# 34
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 test_save(
#       2     model=RuleGenerator(with_reducts=True),
#       3     datasets_folder=Path.cwd() / 'keel-data',
#       4     results_folder=Path.cwd() / 'non-overlap-rules',
#       5     get_rules=True,
#       6     print_info=True,
#       7     include=extra_data_sets,
#       8     verbose=True,
#       9     encode_labels=True
#      10 )
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/quickrules/data_handling.py:142, in test_save(model, datasets_folder, results_folder, get_rules, print_info, exclude, include, verbose, nr_of_folds, encode_labels)
#     139         np.save(f, np.array([1, 3]))
#     141 # create the rules
# --> 142 model.fit(x_train, y_train, t_train)
#     144 # query on the test set
#     145 predictions = model.predict(x_test)
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/_Work/PhD Thesis/2022-fuzzylem/fuzzyroughrules/non_overlap_rules.py:142, in RuleGenerator.fit(self, data, labels, types)
#     140     current_covering = fo.lukasiewicz_t_norm(fo.general_triangular_relation(self.X_scaled, self.X_scaled[i], self.theta, self.reducts[i]), self.positive_region[i])
#     141     covering.append(1*(current_covering > 1e-6))
# --> 142 self.selected_indexes = self.__optimisation_procedure(np.array(covering).T)
#     143 self.n_rules = np.size(self.selected_indexes)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (6168, 6168) + inhomogeneous part.

# %%
import numpy as np

with open(Path.cwd() / 'test.npy', 'wb') as f:
    np.save(f, np.array([1,2]))

# %%
from quickrules.data_handling import get_dataset
# Out:
# array([1, 2])

# %%
classes = np.load(str(Path.cwd() / 'non-overlap-rules' / 'bands' / 'fold1'/"label_encoding_fold1.npy"))

# %%
classes
# Out:
# array(['band', 'noband'], dtype='<U6')
